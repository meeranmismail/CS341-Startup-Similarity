# %% [markdown]
# Below is some starter code to get the IDF vector, and view it so we can start making calculations and generating the graph

# %%
import pandas as pd
import numpy as np

# Read in the IDF vector
idf_vector = pd.read_csv("../data/initial_idf_vector.csv" ,header=None, names=['IDF'], index_col=0, encoding = "ISO-8859-1")
idf_vector
# Out:
#                       IDF
# company          8.537780
# platform         8.239857
# provides         8.230044
# offers           8.223895
# online           8.184793
# develops         8.138565
# users            8.137103
# services         8.128585
# enables          8.113726
# mobile           8.112228
# application      8.103494
# software         8.097426
# technology       8.089789
# allows           8.085487
# helps            8.081784
# products         8.076205
# based            8.073091
# management       8.071843
# data             8.070594
# also             8.069655
# social           8.065265
# digital          8.056744
# business         8.053887
# service          8.053887
# information      8.052615
# development      8.048149
# marketing        8.047510
# operates         8.045909
# using            8.045588
# providing        8.045268
# ...                   ...
# itsnullusers     8.006368
# woundcare        8.006368
# circle           8.006368
# cmv              8.006368
# ruzuku           8.006368
# elevator         8.006368
# freedcamp        8.006368
# imageamplified   8.006368
# alter            8.006368
# andes            8.006368
# printondemand    8.006368
# czechbased       8.006368
# beatbased        8.006368
# asia             8.006368
# usergenerated    8.006368
# kidfriendly      8.006368
# defines          8.006368
# workplace        8.006368
# bioinorganic     8.006368
# unipak           8.006368
# zips             8.006368
# lick             8.006368
# owneroccupied    8.006368
# artistÃ­s        8.006368
# laserprocessing  8.006368
# samplers         8.006368
# instructions     8.006368
# cellscape        8.006368
# 01               8.006368
# NaN              8.006368
#
# [10807 rows x 1 columns]

# %%
# The idf vector can be converted to a numpy array for linear algebra calculatons via these command:

# Get the idf values in a column vector
idf_values_array = idf_vector.values

# Get the words in a column vector. The initial order mathes the values in the idf_values_array
idf_words_array = idf_vector.index.values
# Perform a reshape on the words array to get it in a better format
idf_words_array = idf_words_array.reshape(len(idf_words_array),1)


print("IDF values column vector:\n")
print(idf_values_array)
print("\nCorresponding words column vector:\n")
print(idf_words_array)
# Out:
# IDF values column vector:
#
# [[ 8.53777983]
#  [ 8.23985741]
#  [ 8.23004431]
#  ...,
#  [ 8.00636757]
#  [ 8.00636757]
#  [ 8.00636757]]
#
# Corresponding words column vector:
#
# [['company']
#  ['platform']
#  ['provides']
#  ...,
#  ['cellscape']
#  ['01']
#  [nan]]
