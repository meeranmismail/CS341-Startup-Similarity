# %% [markdown]
# # Initial attempt at creating Naive Bayes and SVM models to perform categorization of companies based on test descriptions and categories.
# ### Note: Most of the sci-kit learn code comes from this tutorial: http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html

# %%
import pandas as pd
# Have a look at the category labeled training data 
full_categories_df = pd.read_csv("data/category_training_labeled_fixed.csv",  encoding = "ISO-8859-1")
print(full_categories_df.shape)
full_categories_df.info()
# Out:
# (3000, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
# domain         3000 non-null object
# rs_category    3000 non-null object
# tx_industry    1669 non-null object
# cb_category    1580 non-null object
# tx_category    1669 non-null object
# pb_desc        2336 non-null object
# cb_desc        2288 non-null object
# pb_industry    1390 non-null object
# pb_category    2335 non-null object
# dtypes: object(9)
# memory usage: 211.0+ KB

# %%
full_categories_df.head()
# Out:
#                   domain                         rs_category  \
# 0     conferencecloud.co  Business Communication Application
# 1           terminus.com      Marketing Software and Service
# 2  galileoprocessing.com                 Payment Application
# 3              pubble.co  Business Communication Application
# 4                cajo.fi                 Printing Technology
#
#                              tx_industry  \
# 0                                    NaN
# 1  AdTech,AdTech,Enterprise Applications
# 2                                Fintech
# 3                                    NaN
# 4                                    NaN
#
#                              cb_category                tx_category  \
# 0                 information technology                        NaN
# 1  advertising|advertising platforms|b2b  AdTech,MarketingTech,SaaS
# 2                                    NaN              Payment Cards
# 3       digital media|education|software                        NaN
# 4                                    NaN                        NaN
#
#                                              pb_desc  \
# 0  Provider of an online conferencing platform. T...
# 1  Developer of a B2B advertising platform. The c...
# 2  Provider of payment processing services. The c...
# 3  Operator of a community engagement platform. T...
# 4  Developer of a stainless steel colour patterni...
#
#                                              cb_desc             pb_industry  \
# 0  ConferenceCloud provides state-of-the-art live...                     NaN
# 1  Terminus is a platform that seamlessly integra...  AdTech, Marketing Tech
# 2           Next generation card processing platform                 FinTech
# 3  Pubble is a messaging platform that simplifies...                     NaN
# 4                                                NaN           Manufacturing
#
#                          pb_category
# 0           Social/Platform Software
# 1     Business/Productivity Software
# 2           Other Financial Services
# 3  Software Development Applications
# 4                    Machinery (B2B)

# %%
# get the distinct categories as labeled by rocketship
labels = full_categories_df['rs_category'].unique()
print(labels)
# Out:
# ['Business Communication Application' 'Marketing Software and Service'
#  'Payment Application' 'Printing Technology' 'Alternative Lending'
#  'Fashion' 'EdTech' 'Biotech & Pharmaceuticals'
#  'Business Equipment and Supplies' 'Social Content'
#  'Business Intelligence Software' 'Industrial Hardware, Supplies and Parts'
#  'Consumer Finance' 'Human Capital Services' 'Food Product'
#  'Personal Care Products and Service' 'Health and Fitness Application'
#  'Medical Equipment' 'Healthcare Information Technology' 'Online Gifting'
#  'Broadcasting, Radio and Television' 'Social Network' 'Data Analytics'
#  'E-commerce Application' 'Travel' 'Software Development Applications'
#  'Hospital and Clinical Service' 'Home Improvements' 'Music and Audio'
#  'Transportation Tech' 'Real Estate' 'Alternative Energy' 'Agriculture'
#  'Construction' 'Environmental Services' 'insurance' 'General Commerce'
#  'Connectivity Products' 'Productivity Applications' 'Database Service'
#  'Electronic Equipment and Hardware' 'Mining' 'Automotive'
#  'Investment Technology' 'Insurance' 'Supply Chain'
#  'Shipping and Forwarding' 'Government' 'Telecommunication' 'Gaming'
#  'Ticketing and Events' 'Cyber Security' 'Navigation and Geographic'
#  'Conglomerates' 'Unmanned Aerial Vehicle' 'Energy Efficiency'
#  'Enterprise Supply Chain' 'Books and References'
#  'personal Care Products and Service' 'Multimedia and Design Software'
#  'Local Delivery' 'Consumer Legal Services' 'Mobile Utility Application'
#  'Consulting Services (B2B)' 'Food Review' 'Edtech'
#  'Infrastructure Application' 'Aquaculture' 'Workflow Automation Software'
#  'Coupons and Deals' 'Aerospace and Defense' 'Traditional Finance'
#  'Weather' 'Accounting, Audit and Tax Services' 'Enterprise Legal Service'
#  'Chemicals' 'E-Commerce Application' 'alternative Lending']

# %%
# Create a dictionary where key = category, integer = unique integer

category_dict = {category: n for n, category in enumerate(labels)}
print(category_dict)
# Out:
# {'Business Communication Application': 0, 'Marketing Software and Service': 1, 'Payment Application': 2, 'Printing Technology': 3, 'Alternative Lending': 4, 'Fashion': 5, 'EdTech': 6, 'Biotech & Pharmaceuticals': 7, 'Business Equipment and Supplies': 8, 'Social Content': 9, 'Business Intelligence Software': 10, 'Industrial Hardware, Supplies and Parts': 11, 'Consumer Finance': 12, 'Human Capital Services': 13, 'Food Product': 14, 'Personal Care Products and Service': 15, 'Health and Fitness Application': 16, 'Medical Equipment': 17, 'Healthcare Information Technology': 18, 'Online Gifting': 19, 'Broadcasting, Radio and Television': 20, 'Social Network': 21, 'Data Analytics': 22, 'E-commerce Application': 23, 'Travel': 24, 'Software Development Applications': 25, 'Hospital and Clinical Service': 26, 'Home Improvements': 27, 'Music and Audio': 28, 'Transportation Tech': 29, 'Real Estate': 30, 'Alternative Energy': 31, 'Agriculture': 32, 'Construction': 33, 'Environmental Services': 34, 'insurance': 35, 'General Commerce': 36, 'Connectivity Products': 37, 'Productivity Applications': 38, 'Database Service': 39, 'Electronic Equipment and Hardware': 40, 'Mining': 41, 'Automotive': 42, 'Investment Technology': 43, 'Insurance': 44, 'Supply Chain': 45, 'Shipping and Forwarding': 46, 'Government': 47, 'Telecommunication': 48, 'Gaming': 49, 'Ticketing and Events': 50, 'Cyber Security': 51, 'Navigation and Geographic': 52, 'Conglomerates': 53, 'Unmanned Aerial Vehicle': 54, 'Energy Efficiency': 55, 'Enterprise Supply Chain': 56, 'Books and References': 57, 'personal Care Products and Service': 58, 'Multimedia and Design Software': 59, 'Local Delivery': 60, 'Consumer Legal Services': 61, 'Mobile Utility Application': 62, 'Consulting Services (B2B)': 63, 'Food Review': 64, 'Edtech': 65, 'Infrastructure Application': 66, 'Aquaculture': 67, 'Workflow Automation Software': 68, 'Coupons and Deals': 69, 'Aerospace and Defense': 70, 'Traditional Finance': 71, 'Weather': 72, 'Accounting, Audit and Tax Services': 73, 'Enterprise Legal Service': 74, 'Chemicals': 75, 'E-Commerce Application': 76, 'alternative Lending': 77}

# %%
# Take the training dataset and perform some operations to combine both descriptions into one column

subset_categories_df = full_categories_df.loc[:,('domain','rs_category')]
subset_categories_df['description'] = full_categories_df[['pb_desc','cb_desc']].fillna('').sum(axis=1)
print(subset_categories_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
# domain         3000 non-null object
# rs_category    3000 non-null object
# description    3000 non-null object
# dtypes: object(3)
# memory usage: 70.4+ KB
# None

# %%
# Now enumerate the categories, so that they can be used in a classification algorithm
subset_categories_df['labels'] = subset_categories_df['rs_category'].map(category_dict).astype(int)

# %%
subset_categories_df.head()
# Out:
#                   domain                         rs_category  \
# 0     conferencecloud.co  Business Communication Application
# 1           terminus.com      Marketing Software and Service
# 2  galileoprocessing.com                 Payment Application
# 3              pubble.co  Business Communication Application
# 4                cajo.fi                 Printing Technology
#
#                                          description  labels
# 0  Provider of an online conferencing platform. T...       0
# 1  Developer of a B2B advertising platform. The c...       1
# 2  Provider of payment processing services. The c...       2
# 3  Operator of a community engagement platform. T...       0
# 4  Developer of a stainless steel colour patterni...       3

# %%
# Now get the company name (assuming it is the domain name) by splitting the domain on '.' 
# store this in a new column called 'company'

subset_categories_df['company'] = subset_categories_df['domain'].str.split('.').str[0]
subset_categories_df.head()
# Out:
#                   domain                         rs_category  \
# 0     conferencecloud.co  Business Communication Application
# 1           terminus.com      Marketing Software and Service
# 2  galileoprocessing.com                 Payment Application
# 3              pubble.co  Business Communication Application
# 4                cajo.fi                 Printing Technology
#
#                                          description  labels  \
# 0  Provider of an online conferencing platform. T...       0
# 1  Developer of a B2B advertising platform. The c...       1
# 2  Provider of payment processing services. The c...       2
# 3  Operator of a community engagement platform. T...       0
# 4  Developer of a stainless steel colour patterni...       3
#
#              company
# 0    conferencecloud
# 1           terminus
# 2  galileoprocessing
# 3             pubble
# 4               cajo

# %%
### Write the company names to a txt file to be used by web scraper script
### Only do this once
import numpy as np
company_name_df = subset_categories_df.loc[:,('domain','company')]
np.savetxt('training_companies.txt', subset_categories_df.domain.values, fmt='%s')

# %%
# An example of where my theory breaks: searching 2020london returns nothing about the company
subset_categories_df.loc[subset_categories_df['domain'] == '2020london.com']
# Out:
#             domain                     rs_category  \
# 37  2020london.com  Marketing Software and Service
#
#                                           description  labels     company
# 37  Provider of mobile marketing services. The com...       1  2020london

# %%
# Now split into training and testing data
num_samp = subset_categories_df.shape[0]
train_index = int(num_samp*2/3 - 1)
test_index = num_samp - 1

# Use these indexes found above to slice the necessary columns into text and training data (70/30 split)
features_train = subset_categories_df["description"][0:train_index].as_matrix()
features_test = subset_categories_df["description"][train_index+1:test_index].as_matrix()

labels_train = subset_categories_df["labels"][0:train_index].as_matrix()
labels_test = subset_categories_df["labels"][train_index+1:test_index].as_matrix()


# Note: If the index is needed, remove the as_matrix function at the end and the data will be stored as a pandas Series
# whcih retians the index (if you shuffle randomly)

# %%
features_train
# Out:
# array([ 'Provider of an online conferencing platform. The company provides an online platform which allows conducting of video conferences.ConferenceCloud provides state-of-the-art live communications and interactivity for hybrid conferences, lectures and meetings.',
#        "Developer of a B2B advertising platform. The company enables B2B marketers to simplify account-based marketing to reach and engage targeted accounts across all stages of the buyer's journey.Terminus is a platform that seamlessly integrate salesforce CRM and build segments of best fit accounts.",
#        'Provider of payment processing services. The company provides pre-paid visa, mastercard and bill payment processing services and also offers its clients business intelligence, analytics and program management services.Next generation card processing platform',
#        ...,
#        'Provider of a localized accounting platform. The company offers a localized industry-specific accounting platform for small and medium enterprises in Asia and South-East Asian countries with collaborative financial management features.The 100% free and localised industry specific accounting platform, built with passion for SMEs and NGOs.',
#        'Provider of a Web-based platform that helps financial institutions to comply with reporting requirements. The company helps accountants in their accounting calculations and reporting for the allowance account.Breakthrough accounting technology',
#        'Getix is a cloud-based POS service for retail stores.'], dtype=object)

# %%
## Now go through all the description columns and get count of each word --> used in other notebook and needed 
# a place to copy it to
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer(stop_words='english')
temp_df = full_categories_df['pb_desc'].fillna('the')
X_train_counts = count_vect.fit_transform(temp_df)
print(X_train_counts.shape)
count_vect.vocabulary_
# Out:
# (3000, 6868)
# {'provider': 4864,
#  'online': 4200,
#  'conferencing': 1363,
#  'platform': 4588,
#  'company': 1278,
#  'provides': 4866,
#  'allows': 261,
#  'conducting': 1357,
#  'video': 6607,
#  'conferences': 1362,
#  'developer': 1797,
#  'b2b': 523,
#  'advertising': 165,
#  'enables': 2105,
#  'marketers': 3702,
#  'simplify': 5675,
#  'account': 78,
#  'based': 569,
#  'marketing': 3703,
#  'reach': 4972,
#  'engage': 2130,
#  'targeted': 6135,
#  'accounts': 82,
#  'stages': 5877,
#  'buyer': 851,
#  'journey': 3352,
#  'payment': 4423,
#  'processing': 4788,
#  'services': 5575,
#  'pre': 4687,
#  'paid': 4332,
#  'visa': 6633,
#  'mastercard': 3714,
#  'offers': 4170,
#  'clients': 1158,
#  'business': 845,
#  'intelligence': 3209,
#  'analytics': 291,
#  'program': 4815,
#  'management': 3670,
#  'operator': 4214,
#  'community': 1273,
#  'engagement': 2132,
#  'software': 5748,
#  'new': 4067,
#  'question': 4925,
#  'answer': 316,
#  'websites': 6733,
#  'changes': 1040,
#  'way': 6718,
#  'interaction': 3217,
#  'owner': 4312,
#  'users': 6528,
#  'continually': 1432,
#  'enhancing': 2144,
#  'website': 6732,
#  'stainless': 5878,
#  'steel': 5909,
#  'colour': 1230,
#  'patterning': 4414,
#  'instrument': 3192,
#  'manufactures': 3687,
#  'laser': 3438,
#  'marking': 3706,
#  'machines': 3632,
#  'branded': 763,
#  'products': 4804,
#  'industrial': 3101,
#  'elements': 2066,
#  'interior': 3232,
#  'decoration': 1685,
#  'items': 3315,
#  'household': 2933,
#  'appliances': 356,
#  'loan': 3575,
#  'modification': 3911,
#  'negotiating': 4044,
#  'repayment': 5147,
#  'terms': 6197,
#  'rates': 4965,
#  'swedish': 6077,
#  'lenders': 3490,
#  'behalf': 602,
#  'customers': 1603,
#  'resale': 5187,
#  'retail': 5231,
#  'fashion': 2352,
#  'develops': 1802,
#  'stores': 5934,
#  'consignment': 1389,
#  'individuals': 3096,
#  'upload': 6510,
#  'sale': 5381,
#  'molecular': 3923,
#  'function': 2581,
#  'diagnosing': 1811,
#  'diseases': 1874,
#  'optimization': 4231,
#  'drug': 1971,
#  'development': 1800,
#  'equipment': 2183,
#  'rental': 5139,
#  'engaged': 2131,
#  'renting': 5141,
#  'servicing': 5576,
#  'scientific': 5439,
#  'test': 6199,
#  'measurement': 3747,
#  'communications': 1269,
#  'lighting': 3524,
#  'organizations': 4258,
#  'engages': 2133,
#  'assessment': 434,
#  'existing': 2257,
#  'arrangements': 398,
#  'know': 3399,
#  'electricity': 2051,
#  'consumption': 1414,
#  'tailor': 6114,
#  'systems': 6104,
#  'looks': 3605,
#  'maintenance': 3653,
#  'web': 6727,
#  'group': 2765,
#  'consolidation': 1396,
#  'reporting': 5162,
#  'advise': 168,
#  'investments': 3268,
#  'stakeholders': 5879,
#  'instant': 3180,
#  'access': 65,
#  'financial': 2418,
#  'statements': 5891,
#  'reports': 5163,
#  'small': 5716,
#  'molecule': 3924,
#  'drugs': 1972,
#  'treatment': 6371,
#  'misfolding': 3886,
#  'protein': 4854,
#  'disorders': 1879,
#  'neurodegenerative': 4060,
#  'age': 191,
#  'related': 5100,
#  'customer': 1602,
#  'application': 358,
#  'automatically': 503,
#  'tagging': 6113,
#  'associating': 448,
#  'businesses': 846,
#  'photo': 4512,
#  'social': 5738,
#  'media': 3761,
#  'sites': 5686,
#  'machine': 3630,
#  'learning': 3472,
#  'technologies': 6165,
#  'transform': 6336,
#  'precision': 4690,
#  'medicine': 3769,
#  'genetic': 2651,
#  'testing': 6200,
#  'diagnostics': 1814,
#  'therapies': 6220,
#  'deep': 1692,
#  'technology': 6166,
#  'aims': 224,
#  'sift': 5656,
#  'millions': 3867,
#  'mutations': 3999,
#  'ones': 4198,
#  'leading': 3463,
#  'disease': 1873,
#  'causal': 997,
#  'interpretation': 3243,
#  'variations': 6563,
#  'revolutionary': 5261,
#  'information': 3119,
#  'clinic': 1161,
#  'laboratory': 3413,
#  'manufacturer': 3685,
#  'handling': 2809,
#  'primarily': 4753,
#  'lifting': 3522,
#  'germany': 2672,
#  'tutorials': 6422,
#  'surveys': 6063,
#  'prepaid': 4712,
#  'debit': 1671,
#  'cards': 947,
#  'capability': 920,
#  'leverages': 3505,
#  'illustrated': 2996,
#  'education': 2025,
#  'rewards': 5264,
#  'helps': 2873,
#  'employees': 2092,
#  'governments': 2724,
#  'industries': 3104,
#  'earn': 1992,
#  'prizes': 4774,
#  'opting': 4236,
#  'paperless': 4359,
#  'wage': 6681,
#  'programs': 4820,
#  'including': 3062,
#  'direct': 1846,
#  'deposits': 1748,
#  'electronic': 2057,
#  'pay': 4418,
#  'stubs': 5972,
#  'payroll': 4425,
#  'career': 949,
#  'network': 4054,
#  'providing': 4867,
#  'employment': 2095,
#  'college': 1226,
#  'students': 5974,
#  'graduates': 2730,
#  'connects': 1383,
#  'alumni': 269,
#  'employers': 2093,
#  'faculty': 2329,
#  'networks': 4057,
#  'colleges': 1227,
#  'universities': 6484,
#  'natural': 4024,
#  'food': 2500,
#  'produces': 4798,
#  'organic': 4253,
#  'seaweed': 5485,
#  'vitamins': 6652,
#  'minerals': 3873,
#  'sells': 5530,
#  'healthcare': 2852,
#  'currently': 1595,
#  'operating': 4209,
#  'stealth': 5907,
#  'mode': 3903,
#  'focuses': 2492,
#  'building': 825,
#  'combination': 1236,
#  'coaching': 1190,
#  'delivery': 1723,
#  'offline': 4176,
#  'channels': 1043,
#  'health': 2851,
#  'training': 6319,
#  'workout': 6818,
#  'dance': 1641,
#  'exercise': 2252,
#  'recorded': 5029,
#  'session': 5578,
#  'music': 3994,
#  'instructor': 3190,
#  'surgical': 6057,
#  'implants': 3029,
#  'tools': 6268,
#  'obstructive': 4147,
#  'sleep': 5707,
#  'apnea': 346,
#  'prelude': 4705,
#  'tongue': 6264,
#  'suspension': 6067,
#  'intraoral': 3252,
#  'devices': 1805,
#  'hypo': 2970,
#  'pharynx': 4502,
#  'connect': 1374,
#  'cancer': 908,
#  'patients': 4411,
#  'families': 2338,
#  'cloud': 1175,
#  'help': 2871,
#  'doctors': 1911,
#  'communicate': 1266,
#  'medication': 3766,
#  'advice': 166,
#  'clinical': 1162,
#  'trials': 6379,
#  'schedules': 5430,
#  'gifting': 2679,
#  'mobile': 3899,
#  'people': 4447,
#  'send': 5537,
#  'personalized': 4476,
#  'drink': 1957,
#  'dinner': 1839,
#  'dessert': 1774,
#  'partner': 4382,
#  'restaurants': 5221,
#  'nightlife': 4079,
#  'venues': 6588,
#  'facebook': 2319,
#  'friends': 2564,
#  'television': 6185,
#  'broadcasting': 800,
#  'operates': 4208,
#  'channel': 1042,
#  'telecasting': 6172,
#  'dating': 1658,
#  'bringing': 794,
#  'shared': 5598,
#  'love': 3613,
#  'applications': 359,
#  'pipeline': 4556,
#  'big': 624,
#  'data': 1649,
#  'advanced': 153,
#  'predicting': 4695,
#  'potential': 4666,
#  'failures': 2332,
#  'pipelines': 4557,
#  'addressing': 135,
#  'emergency': 2080,
#  'situations': 5689,
#  'product': 4800,
#  'exchange': 2243,
#  'manage': 3668,
#  'distribute': 1893,
#  'consumer': 1411,
#  'internet': 3240,
#  'holiday': 2901,
#  'rentals': 5140,
#  'offering': 4168,
#  'apartments': 342,
#  'villas': 6617,
#  'houses': 2936,
#  'chalets': 1033,
#  'accommodation': 73,
#  'homes': 2908,
#  'various': 6567,
#  'countries': 1503,
#  'professional': 4805,
#  'agencies': 192,
#  'private': 4770,
#  'owners': 4313,
#  'smaller': 5717,
#  'promote': 4831,
#  'properties': 4838,
#  'guests': 2778,
#  'chain': 1030,
#  'optical': 4227,
#  'outlets': 4290,
#  'eye': 2308,
#  'frames': 2543,
#  'prescription': 4724,
#  'lenses': 3494,
#  'sunglasses': 6025,
#  'located': 3583,
#  'denmark': 1734,
#  'hardware': 2824,
#  'integration': 3204,
#  'designs': 1767,
#  'enabled': 2104,
#  'future': 2601,
#  'transportation': 6356,
#  'electrification': 2052,
#  'power': 4675,
#  'grid': 2755,
#  'modernization': 3909,
#  'dental': 1736,
#  'care': 948,
#  'like': 3529,
#  'cleaning': 1147,
#  'fillings': 2407,
#  'root': 5329,
#  'canals': 903,
#  'tooth': 6269,
#  'extractions': 2305,
#  'teeth': 6168,
#  'replacements': 5153,
#  'oral': 4240,
#  'surgery': 6056,
#  'cosmetic': 1496,
#  'dentistry': 1737,
#  'mechatronics': 3760,
#  'specializes': 5809,
#  'industrialization': 3102,
#  'pain': 4333,
#  'deliver': 1718,
#  'improved': 3045,
#  'approaches': 367,
#  'localizing': 3580,
#  'tissue': 6258,
#  'degeneration': 1706,
#  'pathologies': 4405,
#  'platforms': 4589,
#  'assessing': 433,
#  'chemistry': 1081,
#  'associated': 447,
#  'degenerative': 1707,
#  'agency': 193,
#  'architecture': 387,
#  'design': 1762,
#  'interactive': 3219,
#  'digital': 1828,
#  'mortgage': 3946,
#  'homebuyers': 2905,
#  'home': 2904,
#  'buyers': 852,
#  'search': 5477,
#  'compare': 1282,
#  'options': 4238,
#  'prices': 4750,
#  'center': 1012,
#  'specially': 5811,
#  'designed': 1763,
#  'perform': 4455,
#  'day': 1659,
#  'procedures': 4784,
#  'require': 5180,
#  'offered': 4166,
#  'doctor': 1910,
#  'office': 4172,
#  'overnight': 4306,
#  'hospital': 2917,
#  'stay': 5902,
#  'provided': 4863,
#  'highly': 2886,
#  'skilled': 5697,
#  'personnel': 4480,
#  'larger': 3436,
#  'facilities': 2325,
#  'travel': 6361,
#  'improving': 3049,
#  'air': 225,
#  'consumers': 1412,
#  'promoting': 4834,
#  'distribution': 1897,
#  'ndc': 4031,
#  'initiative': 3139,
#  'spearheaded': 5803,
#  'international': 3238,
#  'transport': 6355,
#  'association': 449,
#  'iata': 2973,
#  'mattresses': 3732,
#  'sold': 5752,
#  'intermediaries': 3233,
#  'features': 2363,
#  'shape': 5595,
#  'memory': 3787,
#  'polyurethane': 4630,
#  'foam': 2488,
#  'latex': 3446,
#  'high': 2882,
#  'resilience': 5199,
#  'biotechnology': 664,
#  'focused': 2491,
#  'diagnosis': 1812,
#  'pharmaceutical': 4493,
#  'rna': 5297,
#  'sequencing': 5562,
#  'accommodations': 74,
#  'engine': 2135,
#  'complete': 1300,
#  'combining': 1241,
#  'hotels': 2927,
#  'vacation': 6542,
#  'secret': 5489,
#  'deals': 1667,
#  'types': 6431,
#  'monthly': 3942,
#  'subscription': 5992,
#  'box': 753,
#  'service': 5573,
#  'delivering': 1721,
#  'educational': 2026,
#  'games': 2612,
#  'activities': 113,
#  'managed': 3669,
#  'crowdsourcing': 1566,
#  'virtual': 6629,
#  'workforce': 6814,
#  'talent': 6120,
#  'freelancers': 2553,
#  'seeking': 5508,
#  'assignments': 440,
#  'match': 3717,
#  'skill': 5696,
#  'sets': 5581,
#  'collaboration': 1211,
#  'musicians': 3996,
#  'world': 6823,
#  'store': 5931,
#  'projects': 4827,
#  'publishing': 4889,
#  'sharing': 5601,
#  'work': 6809,
#  'retailer': 5232,
#  'beauty': 591,
#  'sell': 5526,
#  'cosmetics': 1497,
#  'personal': 4472,
#  'toxic': 6295,
#  'chemicals': 1079,
#  'spain': 5791,
#  'alzheimerís': 272,
#  'diagnostic': 1813,
#  'detection': 1785,
#  'amyloidgenic': 285,
#  'foreign': 2515,
#  'exchanging': 2244,
#  'kiosks': 3389,
#  'coins': 1207,
#  'notes': 4102,
#  'great': 2747,
#  'british': 796,
#  'pounds': 4671,
#  'euros': 2220,
#  'american': 279,
#  'dollars': 1921,
#  'commerce': 1250,
#  'women': 6801,
#  'underwear': 6462,
#  'shopping': 5633,
#  'lingerie': 3543,
#  'global': 2697,
#  'earth': 1995,
#  'energy': 2127,
#  'known': 3401,
#  'corp': 1486,
#  'formed': 2523,
#  'october': 4159,
#  '22': 22,
#  '2004': 16,
#  'laws': 3456,
#  'state': 5890,
#  'nevada': 4066,
#  'december': 1674,
#  'idc': 2981,
#  'merged': 3801,
#  'ozolutions': 4319,
#  'delaware': 1712,
#  'corporation': 1489,
#  'january': 3325,
#  '10': 1,
#  '1996': 14,
#  'unipak': 6476,
#  'process': 4785,
#  'surviving': 6064,
#  'april': 375,
#  '14': 6,
#  '2006': 17,
#  'changed': 1039,
#  'wataire': 6705,
#  'february': 2365,
#  '2008': 19,
#  'builds': 827,
#  'green': 2750,
#  'alternative': 265,
#  'aid': 218,
#  'crisis': 1553,
#  'relieve': 5113,
#  'greenhouse': 2752,
#  'effect': 2028,
#  'achieve': 89,
#  'objective': 4138,
#  'plans': 4576,
#  'operate': 4206,
#  'million': 3866,
#  'gallon': 2608,
#  'year': 6842,
#  'biodiesel': 639,
#  'pilot': 4549,
#  'plant': 4577,
#  'addition': 128,
#  'production': 4801,
#  'expanding': 2263,
#  'parallel': 4363,
#  'solar': 5751,
#  'wind': 6781,
#  'turbine': 6410,
#  'markets': 3705,
#  'sought': 5776,
#  'entry': 2169,
#  'coal': 1191,
#  'fitness': 2441,
#  'nutrition': 4129,
#  'healthy': 2854,
#  'living': 3570,
#  'maintain': 3649,
#  'weight': 6741,
#  'lifestyle': 3519,
#  'price': 4748,
#  'comparison': 1285,
#  'costs': 1500,
#  'materials': 3723,
#  'lists': 3564,
#  'construction': 1400,
#  'create': 1533,
#  'fan': 2340,
#  'pages': 4331,
#  'integrate': 3200,
#  'commercial': 1251,
#  'environment': 2170,
#  'portable': 4645,
#  'latrine': 3448,
#  'locally': 3581,
#  'owned': 4311,
#  'operated': 4207,
#  'environmentally': 2172,
#  'friendly': 2563,
#  'toilet': 6261,
#  'trash': 6359,
#  'recycling': 5045,
#  'event': 2224,
#  'serve': 5568,
#  'greater': 2748,
#  'austin': 486,
#  'market': 3699,
#  'streaming': 5951,
#  'photos': 4520,
#  'videos': 6609,
#  'directly': 1849,
#  'fresh': 2558,
#  'inspiring': 3170,
#  'experience': 2269,
#  'increases': 3074,
#  'conversions': 1456,
#  'reinsurance': 5094,
#  'insurance': 3197,
#  'risk': 5292,
#  'insurers': 3199,
#  'brokers': 806,
#  'major': 3654,
#  'corporations': 1490,
#  'agents': 195,
#  'banks': 558,
#  'groups': 2766,
#  'immunotherapies': 3021,
#  'research': 5188,
#  'commercialization': 1252,
#  'anti': 322,
#  'therapeutics': 6219,
#  'combat': 1235,
#  'reversing': 5257,
#  'tumor': 6404,
#  'immunosuppression': 3019,
#  'bigdata': 625,
#  'consulting': 1407,
#  'bitcoin': 672,
#  'wallet': 6686,
#  'integrated': 3201,
#  'merchant': 3799,
#  'directory': 1850,
#  'secure': 5493,
#  'easy': 1999,
#  'use': 6524,
#  'making': 3659,
#  'payments': 4424,
#  'enabling': 2106,
#  'develop': 1795,
#  'track': 6300,
#  'communication': 1268,
#  'update': 6505,
#  'phone': 4508,
#  'low': 3616,
#  'cost': 1498,
#  'radiation': 4940,
#  'therapy': 6221,
#  'applies': 360,
#  'genomic': 2656,
#  'analysis': 288,
#  'predict': 4693,
#  'response': 5214,
#  'assist': 441,
#  'oncologists': 4196,
#  'determining': 1793,
#  'optimal': 4229,
#  'level': 3502,
#  'dosing': 1937,
#  'distributor': 1898,
#  'intigrated': 3247,
#  'circuits': 1120,
#  'core': 1482,
#  'multi': 3978,
#  'switch': 6082,
#  'router': 5342,
#  'oems': 4163,
#  'tool': 6267,
#  'unleash': 6487,
#  'productivity': 4803,
#  'general': 2641,
#  'medical': 3764,
#  'inpatient': 3151,
#  'outpatient': 4292,
#  'room': 5327,
#  'include': 3059,
#  'anesthesia': 302,
#  'cardiac': 942,
#  'pulmonary': 4891,
#  'rehabilitation': 5091,
#  'cardiopulmonary': 945,
#  'chemotherapy': 1082,
#  'critical': 1554,
#  'unit': 6479,
#  'imaging': 3003,
#  'department': 1738,
#  'supplies': 6041,
#  'specialty': 5813,
#  'wound': 6829,
#  'proprietary': 4842,
#  'engineered': 2136,
#  'escherichia': 2195,
#  'coli': 1209,
#  'expression': 2295,
#  'soluble': 5757,
#  'recombinant': 5019,
#  'monoclonal': 3939,
#  'antibodies': 326,
#  'therapeutic': 6218,
#  'proteins': 4855,
#  'developed': 1796,
#  'genetically': 2652,
#  'bypasses': 857,
#  'inclusion': 3063,
#  'body': 708,
#  'formation': 2521,
#  'motion': 3953,
#  'control': 1443,
#  'seller': 5527,
#  'marketer': 3701,
#  'electrical': 2049,
#  'motors': 3959,
#  'sweden': 6076,
#  'elemental': 2064,
#  'drill': 1955,
#  'samples': 5392,
#  'exploration': 2279,
#  'mining': 3880,
#  'companies': 1276,
#  'uses': 6529,
#  'instruments': 3195,
#  'withstand': 6799,
#  'harsh': 2828,
#  'environments': 2173,
#  'provide': 4862,
#  'scanning': 5421,
#  'chemical': 1078,
#  'geological': 2666,
#  'expertise': 2276,
#  'specialized': 5808,
#  'lending': 3491,
#  'aircraft': 229,
#  'loans': 3576,
#  'leasing': 3476,
#  'industry': 3105,
#  'driven': 1961,
#  'robots': 5311,
#  'computer': 1333,
#  'vision': 6638,
#  'artificial': 409,
#  'networking': 4056,
#  'ios': 3286,
#  'mac': 3629,
#  'windows': 6782,
#  'think': 6226,
#  'interact': 3216,
#  'caring': 955,
#  'remote': 5125,
#  'assistance': 442,
#  'smart': 5721,
#  'phones': 4510,
#  'tablets': 6108,
#  'dsl': 1975,
#  'fiber': 2396,
#  'stock': 5923,
#  'structured': 5970,
#  'hackers': 2792,
#  'managers': 3672,
#  'demand': 1724,
#  'assigning': 439,
#  'team': 6154,
#  'creating': 1536,
#  'demo': 1728,
#  'finished': 2430,
#  'wood': 6804,
#  'acetylated': 88,
#  'used': 6525,
#  'fabrication': 2315,
#  'panel': 4352,
#  'medium': 3772,
#  'density': 1735,
#  'fibreboard': 2397,
#  'particle': 4379,
#  'board': 703,
#  'dealer': 1664,
#  'cars': 968,
#  'porsche': 4643,
#  'audi': 475,
#  'vehicles': 6578,
#  'bedford': 594,
#  'hand': 2803,
#  'cutting': 1616,
#  'coving': 1519,
#  'skirting': 5702,
#  'brand': 762,
#  'trigjig': 6383,
#  'workers': 6811,
#  'measure': 3746,
#  'guide': 2780,
#  'cuts': 1614,
#  'buildings': 826,
#  'transactional': 6326,
#  'start': 5886,
#  'ups': 6513,
#  'emerging': 2081,
#  'accredited': 83,
#  'investor': 3269,
#  'funding': 2590,
#  'procedure': 4783,
#  'seroma': 5567,
#  'post': 4659,
#  'fluid': 2481,
#  'accumulation': 84,
#  'prevent': 4740,
#  'iron': 3300,
#  'ore': 4250,
#  'pellets': 4441,
#  'north': 4093,
#  'mines': 3874,
#  'pellet': 4440,
#  'plants': 4579,
#  'michigan': 3832,
#  'minnesota': 3882,
#  'connecting': 1377,
#  'sellers': 5528,
#  'buys': 854,
#  'kind': 3386,
#  'safety': 5371,
#  'loyalty': 3621,
#  'buy': 850,
#  'donate': 1925,
#  'transact': 6323,
#  'stream': 5950,
#  'allowing': 260,
#  'tweet': 6426,
#  'action': 106,
#  'reply': 5159,
#  'initiate': 3136,
#  'transaction': 6325,
#  'lab': 3407,
#  'psychology': 4879,
#  'behavioral': 604,
#  'science': 5437,
#  'helping': 2872,
#  'build': 823,
#  'publish': 4884,
#  'results': 5227,
#  'supply': 6042,
#  'visibility': 6636,
#  'freight': 2555,
#  'carriers': 964,
#  'automated': 500,
#  'shippers': 5620,
#  'shipping': 5621,
#  'railway': 4948,
#  'road': 5300,
#  'logistics': 3599,
#  'port': 4644,
#  'operations': 4212,
#  'romania': 5323,
#  'recruiting': 5040,
#  'candidates': 911,
#  'prioritise': 4765,
#  'job': 3339,
#  'flow': 2476,
#  'using': 6531,
#  'algorithms': 250,
#  'recruitment': 5041,
#  'cash': 973,
#  'withdrawals': 6798,
#  'shops': 5634,
#  'scalable': 5416,
#  'prosthetic': 4846,
#  'fitting': 2443,
#  'lower': 3617,
#  'limb': 3533,
#  'sockets': 5742,
#  'processes': 4787,
#  'integrating': 3203,
#  'optimised': 4230,
#  'feedstock': 2375,
#  'powders': 4674,
#  '3d': 35,
#  'printing': 4762,
#  'additive': 130,
#  'manufacturing': 3688,
#  'passenger': 4390,
#  'train': 6315,
#  'bus': 843,
#  'stõ': 5984,
#  'nad': 4012,
#  'labem': 3410,
#  'czech': 1630,
#  'republic': 5174,
#  'heavy': 2862,
#  'trains': 6321,
#  'trailers': 6314,
#  'mass': 3711,
#  'unbanked': 6445,
#  'latin': 3447,
#  'america': 278,
#  'grants': 2734,
#  'sourced': 5782,
#  'entirely': 2162,
#  'scored': 5448,
#  'model': 3904,
#  'solve': 5761,
#  'problems': 4781,
#  'cable': 861,
#  'game': 2609,
#  'templates': 6189,
#  'enable': 2103,
#  'derived': 1756,
#  'content': 1423,
#  'playlist': 4598,
#  'sound': 5777,
#  'tracks': 6305,
#  'collect': 1218,
#  'listen': 3560,
#  'songs': 5767,
#  'youtube': 6854,
#  'soundcloud': 5778,
#  'vimeo': 6618,
#  'dailymotion': 1634,
#  'blogs': 695,
#  'real': 4987,
#  'estate': 2204,
#  'valuation': 6553,
#  'document': 1912,
#  'tracking': 6304,
#  'whirlpool': 6752,
#  'components': 1313,
#  'heaters': 2860,
#  'regulating': 5087,
#  'valves': 6556,
#  'pop': 4636,
#  'light': 3523,
#  'sensors': 5550,
#  'pumps': 4894,
#  'water': 6711,
#  'live': 3569,
#  'fans': 2342,
#  'artists': 413,
#  'concerts': 1345,
#  'tickets': 6240,
#  'leveraging': 3506,
#  'twitter': 6428,
#  'myspace': 4010,
#  'scraping': 5456,
#  'protects': 4853,
#  'theft': 6215,
#  'portals': 4647,
#  'protect': 4849,
#  'bots': 743,
#  'run': 5359,
#  'competitors': 1296,
#  'authorized': 494,
#  'parties': 4381,
#  'developing': 1799,
#  'charging': 1053,
#  'proximity': 4872,
#  'sensor': 5549,
#  'cities': 1123,
#  'public': 4880,
#  'spaces': 5790,
#  'transmitters': 6351,
#  'called': 883,
#  'beacons': 584,
#  'location': 3585,
#  'awareness': 520,
#  'waste': 6703,
#  'tank': 6127,
#  'gas': 2625,
#  'freeing': 2551,
#  'refining': 5066,
#  'pulp': 4892,
#  'paper': 4358,
#  'cataloging': 984,
#  'permanent': 4468,
#  'library': 3510,
#  'allow': 257,
#  'family': 2339,
#  'device': 1804,
#  'attached': 461,
#  'keys': 3381,
#  'pets': 4492,
#  'laptops': 3434,
#  'wallets': 6687,
#  'passport': 4394,
#  'cases': 972,
#  'synchronizes': 6092,
#  'bluetooth': 702,
#  'share': 5596,
#  'grocery': 2763,
#  'list': 3558,
#  'database': 1651,
#  ...}

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

text_clf = Pipeline([('vect', CountVectorizer(stop_words='english')),
                     ('tfidf', TfidfTransformer()),
                     ('clf', MultinomialNB()),
                    ])
text_clf = text_clf.fit(features_train, labels_train)

# %%
# Evaluation of the model
import numpy as np
predicted = text_clf.predict(features_test)
#print(predicted)
np.mean(predicted == labels_test)
# Out:
# 0.24224224224224225

# %%
from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([('vect', CountVectorizer(stop_words='english',ngram_range=(1, 2))),
                     ('tfidf', TfidfTransformer()),
                     ('clf', SGDClassifier(loss='hinge', penalty='l2',
                                           alpha=0.001, n_iter=5, random_state=42)),
])
text_clf_svm = text_clf_svm.fit(features_train, labels_train)

# %%
predicted = text_clf_svm.predict(features_test)
np.mean(predicted == labels_test)
# Out:
# 0.52452452452452447

# %%
from sklearn import metrics
print(metrics.classification_report(labels_test, predicted,
    target_names=labels))
# Out:
#                                          precision    recall  f1-score   support
#
#      Business Communication Application       0.50      0.14      0.22        21
#          Marketing Software and Service       0.55      0.80      0.65        44
#                     Payment Application       0.60      0.82      0.69        11
#                     Printing Technology       0.55      0.86      0.67         7
#                     Alternative Lending       0.47      0.94      0.62        16
#                                 Fashion       0.62      0.75      0.68        20
#                                  EdTech       0.64      0.70      0.67        33
#               Biotech & Pharmaceuticals       0.44      0.84      0.58        63
#         Business Equipment and Supplies       0.00      0.00      0.00         1
#                          Social Content       0.50      0.27      0.35        11
#          Business Intelligence Software       0.71      0.48      0.57        21
# Industrial Hardware, Supplies and Parts       0.25      0.09      0.13        11
#                        Consumer Finance       0.33      0.12      0.18        16
#                  Human Capital Services       0.69      0.65      0.67        34
#                            Food Product       0.58      0.93      0.71        27
#      Personal Care Products and Service       0.61      0.42      0.50        26
#          Health and Fitness Application       0.53      0.44      0.48        18
#                       Medical Equipment       0.62      0.48      0.54        21
#       Healthcare Information Technology       0.55      0.65      0.60        48
#                          Online Gifting       1.00      0.60      0.75         5
#      Broadcasting, Radio and Television       0.60      0.60      0.60         5
#                          Social Network       0.33      0.69      0.44        29
#                          Data Analytics       0.36      0.60      0.45        30
#                  E-commerce Application       0.59      0.43      0.50        23
#                                  Travel       0.50      0.58      0.54        19
#       Software Development Applications       0.38      0.28      0.32        18
#           Hospital and Clinical Service       0.25      0.06      0.10        17
#                       Home Improvements       1.00      0.75      0.86        12
#                         Music and Audio       0.73      0.73      0.73        15
#                     Transportation Tech       0.67      0.31      0.42        13
#                             Real Estate       0.47      0.73      0.57        11
#                      Alternative Energy       0.71      0.50      0.59        10
#                             Agriculture       1.00      0.50      0.67        12
#                            Construction       0.50      0.50      0.50         6
#                  Environmental Services       0.62      0.45      0.53        11
#                               insurance       0.00      0.00      0.00         1
#                        General Commerce       0.00      0.00      0.00         1
#                   Connectivity Products       0.00      0.00      0.00         3
#               Productivity Applications       0.30      0.27      0.29        11
#                        Database Service       0.29      0.15      0.20        13
#       Electronic Equipment and Hardware       0.29      0.35      0.31        23
#                                  Mining       1.00      0.20      0.33         5
#                              Automotive       0.60      0.75      0.67         8
#                   Investment Technology       0.70      0.39      0.50        18
#                               Insurance       0.75      1.00      0.86         9
#                            Supply Chain       0.64      1.00      0.78         7
#                 Shipping and Forwarding       0.50      0.36      0.42        11
#                              Government       0.00      0.00      0.00         2
#                       Telecommunication       0.60      0.25      0.35        12
#                                  Gaming       0.59      0.83      0.69        24
#                    Ticketing and Events       0.67      0.29      0.40         7
#                          Cyber Security       0.50      0.77      0.61        13
#               Navigation and Geographic       0.00      0.00      0.00         3
#                           Conglomerates       0.88      0.78      0.82         9
#                 Unmanned Aerial Vehicle       0.75      0.60      0.67         5
#                       Energy Efficiency       0.50      0.67      0.57         6
#                 Enterprise Supply Chain       0.00      0.00      0.00         4
#                    Books and References       1.00      0.40      0.57         5
#      personal Care Products and Service       0.33      0.22      0.27        18
#          Multimedia and Design Software       0.46      0.60      0.52        10
#                          Local Delivery       0.33      0.20      0.25         5
#                 Consumer Legal Services       0.00      0.00      0.00        20
#              Mobile Utility Application       1.00      0.38      0.55         8
#               Consulting Services (B2B)       0.00      0.00      0.00         4
#                             Food Review       0.00      0.00      0.00         2
#                                  Edtech       0.00      0.00      0.00         5
#              Infrastructure Application       1.00      0.40      0.57         5
#                             Aquaculture       0.00      0.00      0.00         6
#            Workflow Automation Software       1.00      0.12      0.22         8
#                       Coupons and Deals       1.00      0.20      0.33         5
#                   Aerospace and Defense       0.33      0.25      0.29         4
#                     Traditional Finance       0.00      0.00      0.00         1
#                                 Weather       1.00      0.33      0.50         3
#      Accounting, Audit and Tax Services       0.40      0.67      0.50         3
#                Enterprise Legal Service       0.00      0.00      0.00         5
#                               Chemicals       0.00      0.00      0.00         1
#                  E-Commerce Application       0.00      0.00      0.00         1
#
#                             avg / total       0.52      0.52      0.49       999
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'clf__alpha': (1e-2, 1e-3),
}
gs_clf = GridSearchCV(text_clf, parameters, n_jobs=-1)

# %%
gs_clf = gs_clf.fit(features_train, labels_train)
gs_clf.predict(features_test)
#twenty_train.target_names[gs_clf.predict(['God is love'])[0]]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# array([ 6,  8,  4,  9, 18, 21, 42, 27,  7, 12,  7, 43, 24, 16, 59, 43, 40,
#        43, 48, 54, 41, 16, 14, 43, 21, 23, 22, 69, 54, 24,  1, 10,  7,  1,
#         7,  7, 40, 27, 15,  3, 53, 12, 21,  7,  1, 45, 24, 55,  2, 27,  1,
#        11, 12,  7, 22,  1,  1, 32,  7, 21, 59, 22, 29, 38, 10, 21,  4, 60,
#        62, 34,  4, 62, 61, 18,  2, 21,  4, 18,  0,  9, 29,  7, 21, 71,  7,
#        27,  1, 40,  3, 51,  7,  7, 40, 39, 62, 22, 51, 53, 21,  4, 44, 24,
#        21, 22, 18, 15, 26,  6, 21, 45, 13, 16, 21, 21, 22, 25, 13,  1,  1,
#        26, 12, 14, 24, 57,  1, 49, 49,  6, 39,  5, 38, 21, 16,  1, 74, 22,
#        22, 43, 24, 11, 40,  7,  9, 13, 21,  7, 43,  7, 13,  7,  7, 23,  1,
#        10,  1, 49, 21,  6, 45,  7, 18, 40, 14,  6, 16, 29,  1, 25, 21,  7,
#         7,  0, 33, 46,  4, 13, 22, 21, 40,  1,  1,  7,  7, 23, 18, 22, 22,
#        21, 15, 29, 25, 51,  4, 63, 68, 60,  7, 40,  8,  7,  5, 18,  5, 24,
#        27, 22, 13,  9, 10, 61, 28, 53, 21, 15, 69, 17, 15,  7, 40, 15, 22,
#        25, 55, 10, 14, 15, 14, 40,  2,  7,  7, 17, 27, 40, 30, 28,  7,  7,
#        16, 49, 49, 27, 14, 18,  7,  1, 52, 59, 13, 44, 10, 55,  9, 23, 13,
#         1, 74,  1,  3, 13,  7, 11, 13, 63,  1, 26,  6, 60, 10, 34, 30,  4,
#         7, 13, 59, 43, 57, 43, 29, 34, 50,  7, 40, 60, 61,  7, 16, 25, 33,
#        20, 13, 14,  6, 10, 48, 62, 23, 16, 22, 21,  1,  7, 18, 50, 16, 49,
#        22, 69,  5,  7, 22,  6, 32, 22, 14, 49, 21, 21, 46,  6, 18, 59, 38,
#        14, 48,  1, 10,  5, 60,  1,  7, 59, 51,  1, 40, 49, 22, 14, 21,  6,
#         6, 10, 34,  1, 31, 49, 18, 60,  7,  7, 72, 17,  6, 40,  1,  1, 18,
#        11,  7, 24,  5, 62,  7, 26, 13,  1, 21, 59, 49,  6, 15, 65, 21,  7,
#         4,  7, 12,  9,  5, 18, 32, 22, 32, 50,  7, 13, 70, 14,  1, 60, 46,
#         7,  1,  1, 24,  1,  5,  0, 49, 24, 13, 30, 21, 46, 21, 18, 38, 40,
#        60, 40,  7, 28, 33, 59, 12,  4,  7,  1, 25, 18, 12, 15, 22, 48, 51,
#         4, 49, 46, 14, 22,  7, 17,  5, 25, 43,  9, 59, 18,  7, 22,  1, 22,
#        45,  6, 18, 18,  1, 18,  6, 10, 40, 24, 30, 29, 18, 18, 18, 24, 49,
#        14, 63, 16, 30, 18, 51, 15, 18, 10, 40,  0, 25, 21, 13, 14,  5,  2,
#         6,  1, 23, 49,  4, 17, 12, 29, 50, 40, 43,  7,  1, 45,  7, 21, 28,
#         7, 40, 49,  7, 40, 49, 14,  6, 68,  1,  7,  7, 13,  7, 45, 49,  7,
#        40, 43, 13,  1,  6, 57, 21,  7, 28, 31,  7, 59, 21, 18, 26,  7,  1,
#        59, 59,  1, 63, 16,  7, 29,  7,  1, 15, 55,  5, 40, 22, 60, 63,  2,
#        14,  7, 66, 22, 22, 57, 22, 40, 13, 39, 18, 25,  1, 29, 21, 10, 15,
#        31, 33, 59, 49, 24, 31, 18,  5, 21, 21, 11,  1, 47,  5, 51, 31, 12,
#         1,  4, 71, 14,  7,  5, 22,  1, 43,  7, 13, 13, 24, 18, 13, 40,  6,
#        51, 23, 22,  7, 13, 12, 23, 60, 18,  7, 62, 49,  6, 45, 49, 60, 16,
#        59,  2,  1, 22,  4,  7, 23, 17, 12, 15,  4, 46, 18, 24, 44, 21, 17,
#        33, 29, 16, 42, 15,  7, 16, 22,  1, 23, 18, 21, 20, 30, 44, 14,  7,
#        21, 62, 53, 53, 21, 42, 30, 22,  1, 40, 23, 53, 21, 10,  1,  7, 39,
#        40, 51, 38, 48,  6, 18, 63,  3, 34,  3, 40, 10, 45, 59,  7, 18, 30,
#         1, 49,  7, 18,  7, 62,  4, 28, 31, 11, 14, 30, 55, 14,  0, 21, 49,
#         7,  7, 28, 57,  1,  1,  1, 13,  7, 10, 60, 18,  4, 16, 42, 21,  6,
#        22,  6, 10,  7, 18, 45, 40,  1,  7, 14,  5, 40, 32, 18, 66, 21,  0,
#        51,  4, 16, 16,  6, 18, 42, 66, 40,  5, 74,  4, 10,  1, 23,  5, 28,
#         1, 43, 23, 24, 31, 12,  7,  7,  5, 18, 21, 43, 15, 59, 63, 32, 18,
#        53, 61, 14, 44,  1, 13, 18, 14, 53,  2, 29, 69, 13, 54, 13, 51,  4,
#        40, 10, 10, 71, 30, 55, 21,  7, 13, 22, 28, 73,  6, 39, 21, 68, 26,
#         1, 38, 21, 18, 10, 43,  7, 22, 62, 29, 27, 18,  7, 21, 22, 21, 52,
#         6, 27,  3,  6, 14, 21, 18, 51, 40, 21,  7, 23, 12,  7, 18, 59, 40,
#        62, 18, 13, 49, 18,  7,  7, 59, 26, 21,  1, 49, 22,  0, 34,  7, 15,
#         1,  1, 22, 16, 18, 16,  1, 30,  4, 24, 21, 62, 14,  7,  7, 26,  2,
#        18, 18, 74,  7, 18, 18, 22, 20,  7, 13, 60,  6,  1,  9, 45, 18, 15,
#        10, 23,  6, 10, 22, 13,  1,  7, 29,  9, 40, 40,  6, 60, 22, 40,  7,
#        21,  4, 22, 40, 53, 21, 16,  3, 43, 38, 18,  1,  1, 18,  7,  4, 68,
#        34, 16,  6, 25, 18,  7, 15,  7, 12, 13, 26, 40,  7,  1, 22, 21, 18,
#        29, 23, 11, 71, 12, 51, 14,  7, 51, 62, 16, 19, 10, 59, 44, 22, 49,
#        31,  5, 36, 57,  6, 40, 21, 29, 38, 21, 70, 60,  6, 25, 32,  3, 40,
#        13,  7, 22,  7, 14,  1, 38,  4,  5,  1, 40, 18,  7, 60, 17,  1,  7,
#        15, 14, 22,  7,  1, 14, 43, 15, 17, 43, 21, 13, 43])

# %%
print(gs_clf.best_score_)                                 

for param_name in sorted(parameters.keys()):
    print("%s: %r" % (param_name, gs_clf.best_params_[param_name]))
# Out:
# 0.473236618309
# clf__alpha: 0.001
# tfidf__use_idf: True
# vect__ngram_range: (1, 2)

# %%
import pandas as pd
# Have a look at the train_pairs data
# Not going to use this data right away, will need later
# If needed, here is code to look at the raw data
#raw_df = pd.read_csv("raw_data_fixed.csv", encoding = "ISO-8859-1",\
#                usecols = ["domain","tx_industry", "cb_category", "tx_category", "cb_desc", "pb_desc", "pb_category"])
#raw_df.head()
train_pairs_df = pd.read_csv("data/company_pairs_training.csv")
print(train_pairs_df.shape)
train_pairs_df.head()
# Out:
# (3000, 17)
#           domain1             domain2  rating  \
# 0  stockflare.com          sigfig.com       2
# 1        2trg.com              2u.com       3
# 2   ntsretail.com        iqmetrix.com       1
# 3   hootsuite.com  hearsaysystems.com       2
# 4     mozenda.com             dexi.io       3
#
#                                         tx_industry1  \
# 0            Fintech,Fintech,Enterprise Applications
# 1                                                NaN
# 2                                                NaN
# 3  AdTech,Enterprise Applications,Enterprise Appl...
# 4                          Enterprise Infrastructure
#
#                                         cb_category1  \
# 0                analytics|big data|personal finance
# 1  Provider of waste recycling services. The comp...
# 2                                                NaN
# 3  advertising|apps|brand marketing|messaging|soc...
# 4                    analytics|business intelligence
#
#                                         tx_category1  \
# 0   Mobile Finance,Investment Tech,Data as a Service
# 1                       Environmental Services (B2B)
# 2                                                NaN
# 3  MarketingTech,SaaS,Customer Service Software,H...
# 4                                        Open Source
#
#                                             pb_desc1  \
# 0  Operator of an online platform for stock manag...
# 1                                          CleanTech
# 2                                                NaN
# 3  Provider of a social media management system. ...
# 4  Provider of data software program that gathers...
#
#                                             cb_desc1  \
# 0  Stockflare helps anyone find new stock ideas. ...
# 1                                                NaN
# 2  NTS Retail provides high-end retail management...
# 3  Hootsuite is the world's most widely used plat...
# 4  Mozenda automates data collection from the web...
#
#                          pb_industry1                          pb_category1  \
# 0                       FinTech, SaaS            Information Services (B2C)
# 1                                 NaN                Environmental Services
# 2                                 NaN                                   NaN
# 3                                SaaS  Media and Information Services (B2B)
# 4  Big Data, Internet of Things, SaaS          Automation/Workflow Software
#
#                                       tx_industry2  \
# 0                                  Fintech,Fintech
# 1            Edtech,Enterprise Applications,Edtech
# 2                          Enterprise Applications
# 3                                              NaN
# 4  Enterprise Applications,Enterprise Applications
#
#                                         cb_category2  \
# 0              accounting|finance|financial services
# 1  Provider of online higher education services. ...
# 2  customer service|digital signage|point of sale...
# 3  digital marketing|financial services|marketing...
# 4            analytics|big data|data mining|software
#
#                      tx_category2  \
# 0  Consumer Finance,Robo Advisors
# 1            Educational Software
# 2                      RetailTech
# 3                             NaN
# 4      Business Intelligence,SaaS
#
#                                             pb_desc2  \
# 0  Provider of an investment services and wealth ...
# 1                                               SaaS
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             cb_desc2  \
# 0  SigFig is the easiest way to manage your money...
# 1  2U is a cloud-based Software-as-a-Service plat...
# 2  iQmetrix is an IT and service company that pro...
# 3  Hearsay offers the complete client engagement ...
# 4  Extract, Enrich & Connect ANY data. Web data e...
#
#                                 pb_industry2        pb_category2
# 0                              FinTech, SaaS  Financial Software
# 1  cloud computing|edtech|education|software              EdTech
# 2                                        NaN                 NaN
# 3                                        NaN                 NaN
# 4                                        NaN                 NaN
